# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key.
from configv1 import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
   
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | bayan
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | peniche
# Processing Record 5 of Set 1 | uchaly
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | mandalgovi
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | sibu
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | paris
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | acapulco
# Processing Record 16 of Set 1 | broome
# Processing Record 17 of Set 1 | elat
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | dingle
# Processing Record 20 of Set 1 | paita
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | san cristobal
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | karatuzskoye
# Processing Record 27 of Set 1 | manzil salim
# Processing Record 28 of Set 1 | saint-pierre
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | karratha
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | rafraf
# Processing Record 39 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | morristown
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | kirkland lake
# Processing Record 50 of Set 1 | biltine
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | cuamba
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | necochea
# Processing Record 7 of Set 2 | aksu
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | taquari
# Processing Record 11 of Set 2 | micheweni
# Processing Record 12 of Set 2 | vila do maio
# Processing Record 13 of Set 2 | hwange
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 2 | shakawe
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | sinop
# Processing Record 20 of Set 2 | pangnirtung
# Processing Record 21 of Set 2 | najran
# Processing Record 22 of Set 2 | porto belo
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | malumfashi
# Processing Record 26 of Set 2 | tashtagol
# Processing Record 27 of Set 2 | puerto madryn
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | kidal
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | porto novo
# Processing Record 32 of Set 2 | el prat de llobregat
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | cayeli
# Processing Record 36 of Set 2 | xining
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | cabo san lucas
# Processing Record 39 of Set 2 | changping
# Processing Record 40 of Set 2 | yarada
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | caramay
# Processing Record 43 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 2 | rancho palos verdes
# Processing Record 45 of Set 2 | zheleznodorozhnyy
# Processing Record 46 of Set 2 | samarai
# Processing Record 47 of Set 2 | acarau
# Processing Record 48 of Set 2 | amurzet
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | ligayan
# Processing Record 1 of Set 3 | alvor
# Processing Record 2 of Set 3 | bereda
# Processing Record 3 of Set 3 | lisala
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | sidney
# Processing Record 6 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | saint anthony
# Processing Record 12 of Set 3 | oktyabrskiy
# Processing Record 13 of Set 3 | puerto carreno
# Processing Record 14 of Set 3 | bandar
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | phimai
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | cherepovets
# Processing Record 23 of Set 3 | vila franca do campo
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | boende
# Processing Record 26 of Set 3 | russell
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | baicoi
# Processing Record 29 of Set 3 | wanning
# Processing Record 30 of Set 3 | caidian
# Processing Record 31 of Set 3 | san jose
# Processing Record 32 of Set 3 | praia
# Processing Record 33 of Set 3 | conde
# Processing Record 34 of Set 3 | katha
# City not found. Skipping...
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | khorixas
# Processing Record 37 of Set 3 | alzamay
# Processing Record 38 of Set 3 | rodrigues alves
# Processing Record 39 of Set 3 | whitehorse
# Processing Record 40 of Set 3 | sao filipe
# Processing Record 41 of Set 3 | leh
# Processing Record 42 of Set 3 | yulara
# Processing Record 43 of Set 3 | yatou
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | victor harbor
# Processing Record 1 of Set 4 | suntar
# Processing Record 2 of Set 4 | san javier
# Processing Record 3 of Set 4 | esil
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | maicao
# Processing Record 6 of Set 4 | jyvaskyla
# Processing Record 7 of Set 4 | uwajima
# Processing Record 8 of Set 4 | sur
# Processing Record 9 of Set 4 | ambon
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | ghazipur
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | vestmanna
# Processing Record 14 of Set 4 | new norfolk
# Processing Record 15 of Set 4 | kurilsk
# Processing Record 16 of Set 4 | tazovskiy
# Processing Record 17 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 4 | shingu
# Processing Record 19 of Set 4 | viadana
# Processing Record 20 of Set 4 | sanger
# Processing Record 21 of Set 4 | anadyr
# Processing Record 22 of Set 4 | banda aceh
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | namanyere
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | la suiza
# Processing Record 27 of Set 4 | tuktoyaktuk
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | kommunar
# Processing Record 31 of Set 4 | urbano santos
# Processing Record 32 of Set 4 | wasilla
# Processing Record 33 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 4 | ribeira grande
# Processing Record 35 of Set 4 | vostok
# Processing Record 36 of Set 4 | rudbar
# Processing Record 37 of Set 4 | havre-saint-pierre
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | itarantim
# Processing Record 42 of Set 4 | kupang
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | waipawa
# Processing Record 45 of Set 4 | labuhan
# Processing Record 46 of Set 4 | palmer
# Processing Record 47 of Set 4 | centralia
# Processing Record 48 of Set 4 | north bend
# Processing Record 49 of Set 4 | brenham
# Processing Record 50 of Set 4 | manta
# Processing Record 1 of Set 5 | balabac
# Processing Record 2 of Set 5 | mattru
# Processing Record 3 of Set 5 | karangasem
# Processing Record 4 of Set 5 | bac lieu
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | howard springs
# Processing Record 8 of Set 5 | ugoofaaru
# Processing Record 9 of Set 5 | bredasdorp
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | fort nelson
# Processing Record 12 of Set 5 | vanavara
# Processing Record 13 of Set 5 | isangel
# Processing Record 14 of Set 5 | akyab
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | verdun
# Processing Record 17 of Set 5 | asfi
# Processing Record 18 of Set 5 | saint-georges
# Processing Record 19 of Set 5 | tarasovskiy
# Processing Record 20 of Set 5 | impfondo
# Processing Record 21 of Set 5 | los alamos
# Processing Record 22 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 5 | muros
# Processing Record 24 of Set 5 | yumen
# Processing Record 25 of Set 5 | nome
# Processing Record 26 of Set 5 | richards bay
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | koupela
# Processing Record 29 of Set 5 | hanzhong
# Processing Record 30 of Set 5 | bagaces
# Processing Record 31 of Set 5 | aklavik
# Processing Record 32 of Set 5 | dolinsk
# Processing Record 33 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 5 | jalu
# Processing Record 35 of Set 5 | tromso
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | caruray
# Processing Record 39 of Set 5 | tigre
# Processing Record 40 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 5 | amahai
# Processing Record 42 of Set 5 | aykhal
# Processing Record 43 of Set 5 | tangping
# Processing Record 44 of Set 5 | eirunepe
# Processing Record 45 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | lagoa
# Processing Record 47 of Set 5 | marsa matruh
# Processing Record 48 of Set 5 | zhigansk
# Processing Record 49 of Set 5 | wewak
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | verkhnevilyuysk
# Processing Record 3 of Set 6 | yeppoon
# Processing Record 4 of Set 6 | sao paulo de olivenca
# Processing Record 5 of Set 6 | port macquarie
# Processing Record 6 of Set 6 | zapolyarnyy
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | poum
# Processing Record 9 of Set 6 | uroteppa
# City not found. Skipping...
# Processing Record 10 of Set 6 | pampa
# Processing Record 11 of Set 6 | puerto ayora
# Processing Record 12 of Set 6 | morondava
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | sao borja
# Processing Record 15 of Set 6 | carnarvon
# Processing Record 16 of Set 6 | dondo
# Processing Record 17 of Set 6 | kisangani
# Processing Record 18 of Set 6 | jinchang
# Processing Record 19 of Set 6 | knysna
# Processing Record 20 of Set 6 | tayoltita
# Processing Record 21 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 6 | boma
# Processing Record 23 of Set 6 | dehloran
# Processing Record 24 of Set 6 | puerto escondido
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | ushtobe
# Processing Record 27 of Set 6 | sturgeon falls
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | frydlant nad ostravici
# Processing Record 30 of Set 6 | cabo rojo
# Processing Record 31 of Set 6 | san juan
# Processing Record 32 of Set 6 | chute-aux-outardes
# Processing Record 33 of Set 6 | padilla
# Processing Record 34 of Set 6 | atar
# Processing Record 35 of Set 6 | westport
# Processing Record 36 of Set 6 | namwala
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | goderich
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | ponta delgada
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | kutiyana
# Processing Record 44 of Set 6 | fare
# Processing Record 45 of Set 6 | scarborough
# Processing Record 46 of Set 6 | boromo
# Processing Record 47 of Set 6 | topolobampo
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | ixtapa
# Processing Record 50 of Set 6 | arcata
# Processing Record 1 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 7 | bethel
# Processing Record 3 of Set 7 | olavarria
# Processing Record 4 of Set 7 | raga
# Processing Record 5 of Set 7 | athens
# Processing Record 6 of Set 7 | yining
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | gigmoto
# Processing Record 9 of Set 7 | cabinda
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | kaitangata
# Processing Record 12 of Set 7 | coihueco
# Processing Record 13 of Set 7 | airai
# Processing Record 14 of Set 7 | vorkuta
# Processing Record 15 of Set 7 | padang
# Processing Record 16 of Set 7 | chupei
# City not found. Skipping...
# Processing Record 17 of Set 7 | bilma
# Processing Record 18 of Set 7 | te anau
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | bemidji
# Processing Record 21 of Set 7 | carbonia
# Processing Record 22 of Set 7 | kenai
# Processing Record 23 of Set 7 | pacifica
# Processing Record 24 of Set 7 | naklo nad notecia
# Processing Record 25 of Set 7 | orotukan
# Processing Record 26 of Set 7 | dudinka
# Processing Record 27 of Set 7 | aswan
# Processing Record 28 of Set 7 | texarkana
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 7 | mbale
# Processing Record 32 of Set 7 | san miguel
# Processing Record 33 of Set 7 | saint-philippe
# Processing Record 34 of Set 7 | ilulissat
# Processing Record 35 of Set 7 | talakan
# Processing Record 36 of Set 7 | jaguaruna
# Processing Record 37 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 7 | sampit
# Processing Record 39 of Set 7 | boundiali
# Processing Record 40 of Set 7 | finnsnes
# Processing Record 41 of Set 7 | flinders
# Processing Record 42 of Set 7 | rtishchevo
# Processing Record 43 of Set 7 | aripuana
# Processing Record 44 of Set 7 | coihaique
# Processing Record 45 of Set 7 | szilvasvarad
# Processing Record 46 of Set 7 | herat
# Processing Record 47 of Set 7 | kampot
# Processing Record 48 of Set 7 | banganapalle
# Processing Record 49 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | price
# Processing Record 2 of Set 8 | daru
# Processing Record 3 of Set 8 | pontes e lacerda
# Processing Record 4 of Set 8 | saint george
# Processing Record 5 of Set 8 | maragogi
# Processing Record 6 of Set 8 | oranjemund
# Processing Record 7 of Set 8 | almaty
# Processing Record 8 of Set 8 | yerbogachen
# Processing Record 9 of Set 8 | ouallam
# Processing Record 10 of Set 8 | mackay
# Processing Record 11 of Set 8 | miandrivazo
# Processing Record 12 of Set 8 | entroncamento
# Processing Record 13 of Set 8 | bolivar
# Processing Record 14 of Set 8 | chavakkad
# Processing Record 15 of Set 8 | livingstonia
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | wau
# Processing Record 18 of Set 8 | deer lake
# Processing Record 19 of Set 8 | victoria
# Processing Record 20 of Set 8 | lander
# Processing Record 21 of Set 8 | bubaque
# Processing Record 22 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 23 of Set 8 | port-gentil
# Processing Record 24 of Set 8 | kingston
# Processing Record 25 of Set 8 | gawler
# Processing Record 26 of Set 8 | moron
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | chinchani
# Processing Record 30 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 8 | beringovskiy
# Processing Record 32 of Set 8 | oyem
# Processing Record 33 of Set 8 | krasnoselkup
# Processing Record 34 of Set 8 | kuytun
# Processing Record 35 of Set 8 | bukama
# Processing Record 36 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 37 of Set 8 | hede
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | dunedin
# Processing Record 40 of Set 8 | torres
# Processing Record 41 of Set 8 | bahia honda
# Processing Record 42 of Set 8 | cayenne
# Processing Record 43 of Set 8 | khuzdar
# Processing Record 44 of Set 8 | esperance
# Processing Record 45 of Set 8 | alvand
# Processing Record 46 of Set 8 | husavik
# Processing Record 47 of Set 8 | mezen
# Processing Record 48 of Set 8 | jumla
# Processing Record 49 of Set 8 | orlik
# Processing Record 50 of Set 8 | tairua
# Processing Record 1 of Set 9 | selty
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | dubai
# Processing Record 4 of Set 9 | requena
# Processing Record 5 of Set 9 | aleksandrov gay
# Processing Record 6 of Set 9 | svetlaya
# Processing Record 7 of Set 9 | rio grande
# Processing Record 8 of Set 9 | brownsville
# Processing Record 9 of Set 9 | bulgan
# Processing Record 10 of Set 9 | mayo
# Processing Record 11 of Set 9 | alcantara
# Processing Record 12 of Set 9 | cherskiy
# Processing Record 13 of Set 9 | balakhninskiy
# Processing Record 14 of Set 9 | dicabisagan
# Processing Record 15 of Set 9 | gamba
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | moerai
# Processing Record 18 of Set 9 | teshie
# Processing Record 19 of Set 9 | straumen
# Processing Record 20 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 9 | hambantota
# Processing Record 22 of Set 9 | sungaipenuh
# Processing Record 23 of Set 9 | singur
# Processing Record 24 of Set 9 | vila
# Processing Record 25 of Set 9 | sheltozero
# Processing Record 26 of Set 9 | severo-yeniseyskiy
# Processing Record 27 of Set 9 | conroe
# Processing Record 28 of Set 9 | batagay-alyta
# Processing Record 29 of Set 9 | kamina
# Processing Record 30 of Set 9 | port hardy
# Processing Record 31 of Set 9 | sandpoint
# Processing Record 32 of Set 9 | bud
# Processing Record 33 of Set 9 | pamplona
# Processing Record 34 of Set 9 | port augusta
# Processing Record 35 of Set 9 | shimanovsk
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | santo antonio do leverger
# Processing Record 38 of Set 9 | san francisco
# Processing Record 39 of Set 9 | chalus
# Processing Record 40 of Set 9 | talaya
# Processing Record 41 of Set 9 | eureka
# Processing Record 42 of Set 9 | durango
# Processing Record 43 of Set 9 | bourail
# Processing Record 44 of Set 9 | chapais
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | tabou
# Processing Record 47 of Set 9 | zyryanka
# Processing Record 48 of Set 9 | kelo
# Processing Record 49 of Set 9 | panvel
# Processing Record 50 of Set 9 | half moon bay
# Processing Record 1 of Set 10 | guiyang
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | tevriz
# Processing Record 4 of Set 10 | shenjiamen
# Processing Record 5 of Set 10 | opuwo
# Processing Record 6 of Set 10 | sinnamary
# Processing Record 7 of Set 10 | mayenne
# Processing Record 8 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 9 of Set 10 | ajdabiya
# Processing Record 10 of Set 10 | blagoyevo
# Processing Record 11 of Set 10 | xingcheng
# Processing Record 12 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 10 | edd
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | san patricio
# Processing Record 16 of Set 10 | skowhegan
# Processing Record 17 of Set 10 | khor
# Processing Record 18 of Set 10 | rabo de peixe
# Processing Record 19 of Set 10 | inca
# Processing Record 20 of Set 10 | cabedelo
# Processing Record 21 of Set 10 | burica
# City not found. Skipping...
# Processing Record 22 of Set 10 | ajuchitlan
# Processing Record 23 of Set 10 | guozhen
# Processing Record 24 of Set 10 | tocopilla
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | peterhead
# Processing Record 27 of Set 10 | bunbury
# Processing Record 28 of Set 10 | takoradi
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | pozo colorado
# Processing Record 31 of Set 10 | hamilton
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | derzhavinsk
# Processing Record 34 of Set 10 | ostrovnoy
# Processing Record 35 of Set 10 | iquitos
# Processing Record 36 of Set 10 | payakumbuh
# Processing Record 37 of Set 10 | fayaoue
# Processing Record 38 of Set 10 | finschhafen
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | camacha
# Processing Record 41 of Set 10 | inhambane
# Processing Record 42 of Set 10 | korem
# Processing Record 43 of Set 10 | sarkand
# Processing Record 44 of Set 10 | naze
# Processing Record 45 of Set 10 | lovington
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | pisco
# Processing Record 48 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 10 | tuatapere
# Processing Record 50 of Set 10 | kudahuvadhoo
# Processing Record 1 of Set 11 | coquimbo
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | the valley
# Processing Record 4 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 11 | nyagan
# Processing Record 6 of Set 11 | chernyanka
# Processing Record 7 of Set 11 | nalut
# Processing Record 8 of Set 11 | klaksvik
# Processing Record 9 of Set 11 | kununurra
# Processing Record 10 of Set 11 | padre bernardo
# Processing Record 11 of Set 11 | rogun
# City not found. Skipping...
# Processing Record 12 of Set 11 | luxor
# Processing Record 13 of Set 11 | khani
# Processing Record 14 of Set 11 | tezu
# Processing Record 15 of Set 11 | sooke
# Processing Record 16 of Set 11 | maceio
# Processing Record 17 of Set 11 | khonsa
# Processing Record 18 of Set 11 | tibiri
# Processing Record 19 of Set 11 | bonavista
# Processing Record 20 of Set 11 | markova
# Processing Record 21 of Set 11 | srednekolymsk
# Processing Record 22 of Set 11 | krasnyy chikoy
# Processing Record 23 of Set 11 | quelimane
# Processing Record 24 of Set 11 | la grande
# Processing Record 25 of Set 11 | butembo
# Processing Record 26 of Set 11 | mindelheim
# Processing Record 27 of Set 11 | anchorage
# Processing Record 28 of Set 11 | sal rei
# Processing Record 29 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 30 of Set 11 | esmeralda
# Processing Record 31 of Set 11 | shimoda
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 11 | petrolina
# Processing Record 36 of Set 11 | visnes
# Processing Record 37 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 11 | qax
# Processing Record 39 of Set 11 | negotin
# Processing Record 40 of Set 11 | banjar
# Processing Record 41 of Set 11 | coronado
# Processing Record 42 of Set 11 | wattegama
# Processing Record 43 of Set 11 | darnah
# Processing Record 44 of Set 11 | marienburg
# Processing Record 45 of Set 11 | provost
# Processing Record 46 of Set 11 | harper
# Processing Record 47 of Set 11 | payson
# Processing Record 48 of Set 11 | tadine
# Processing Record 49 of Set 11 | passo fundo
# Processing Record 50 of Set 11 | ojinaga
# Processing Record 1 of Set 12 | sakakah
# Processing Record 2 of Set 12 | pulgaon
# Processing Record 3 of Set 12 | chumphon
# Processing Record 4 of Set 12 | libertador general san martin
# Processing Record 5 of Set 12 | leningradskiy
# Processing Record 6 of Set 12 | gaoyou
# Processing Record 7 of Set 12 | bosconia
# Processing Record 8 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 9 of Set 12 | vozhega
# Processing Record 10 of Set 12 | kilindoni
# Processing Record 11 of Set 12 | serebryanyy bor
# Processing Record 12 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 12 | kalabo
# Processing Record 14 of Set 12 | champerico
# Processing Record 15 of Set 12 | rognan
# Processing Record 16 of Set 12 | semey
# Processing Record 17 of Set 12 | nelson bay
# Processing Record 18 of Set 12 | carutapera
# Processing Record 19 of Set 12 | kachiry
# Processing Record 20 of Set 12 | holme
# Processing Record 21 of Set 12 | miri
# Processing Record 22 of Set 12 | seoul
# Processing Record 23 of Set 12 | makat
# Processing Record 24 of Set 12 | lodja
# Processing Record 25 of Set 12 | kaeo
# Processing Record 26 of Set 12 | aktash
# Processing Record 27 of Set 12 | atambua
# Processing Record 28 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 12 | sydney
# Processing Record 30 of Set 12 | lamu
# Processing Record 31 of Set 12 | pinega
# Processing Record 32 of Set 12 | salinopolis
# Processing Record 33 of Set 12 | santa rosalia
# Processing Record 34 of Set 12 | azangaro
# Processing Record 35 of Set 12 | dasoguz
# Processing Record 36 of Set 12 | batemans bay
# Processing Record 37 of Set 12 | hoi an
# Processing Record 38 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 12 | santo domingo de guzman
# Processing Record 40 of Set 12 | dauriya
# Processing Record 41 of Set 12 | costinesti
# Processing Record 42 of Set 12 | kikwit
# Processing Record 43 of Set 12 | tecoanapa
# Processing Record 44 of Set 12 | pevek
# Processing Record 45 of Set 12 | salisbury
# Processing Record 46 of Set 12 | virginia beach
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | gerash
# Processing Record 49 of Set 12 | puerto cabezas
# Processing Record 50 of Set 12 | brae
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | calbuco
# Processing Record 3 of Set 13 | vogan
# Processing Record 4 of Set 13 | tottori
# Processing Record 5 of Set 13 | axim
# Processing Record 6 of Set 13 | chany
# Processing Record 7 of Set 13 | izhma
# Processing Record 8 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 13 | svetlogorsk
# Processing Record 10 of Set 13 | port hedland
# Processing Record 11 of Set 13 | laguna
# Processing Record 12 of Set 13 | verkhnyaya toyma
# Processing Record 13 of Set 13 | bonfim
# Processing Record 14 of Set 13 | nyaunglebin
# Processing Record 15 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 13 | saint-remi
# Processing Record 17 of Set 13 | inuvik
# Processing Record 18 of Set 13 | cedro
# Processing Record 19 of Set 13 | bharwari
# Processing Record 20 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 13 | vallenar
# Processing Record 22 of Set 13 | maldonado
# Processing Record 23 of Set 13 | isla mujeres
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | lotofaga
# Processing Record 26 of Set 13 | jacutinga
# Processing Record 27 of Set 13 | dibulla
# Processing Record 28 of Set 13 | gravelbourg
# Processing Record 29 of Set 13 | rawson
# Processing Record 30 of Set 13 | weston
# Processing Record 31 of Set 13 | malacacheta
# Processing Record 32 of Set 13 | darhan
# Processing Record 33 of Set 13 | blyth
# Processing Record 34 of Set 13 | genhe
# Processing Record 35 of Set 13 | nishihara
# Processing Record 36 of Set 13 | araouane
# Processing Record 37 of Set 13 | denia
# Processing Record 38 of Set 13 | trzebiatow
# Processing Record 39 of Set 13 | aksarka
# Processing Record 40 of Set 13 | tsabong
# Processing Record 41 of Set 13 | kemijarvi
# Processing Record 42 of Set 13 | codrington
# Processing Record 43 of Set 13 | hovd
# Processing Record 44 of Set 13 | cheremukhovo
# Processing Record 45 of Set 13 | karasjok
# Processing Record 46 of Set 13 | saint-louis
# Processing Record 47 of Set 13 | lakes entrance
# Processing Record 48 of Set 13 | pundaguitan
# Processing Record 49 of Set 13 | sobolevo
# Processing Record 50 of Set 13 | hay river
# Processing Record 1 of Set 14 | moreira sales
# Processing Record 2 of Set 14 | pullman
# Processing Record 3 of Set 14 | empalme
# Processing Record 4 of Set 14 | borogontsy
# Processing Record 5 of Set 14 | burnie
# Processing Record 6 of Set 14 | comodoro rivadavia
# Processing Record 7 of Set 14 | ternate
# Processing Record 8 of Set 14 | zemio
# Processing Record 9 of Set 14 | sidi ali
# Processing Record 10 of Set 14 | san rafael
# Processing Record 11 of Set 14 | gisborne
# Processing Record 12 of Set 14 | oistins
# Processing Record 13 of Set 14 | steamboat springs
# Processing Record 14 of Set 14 | bumba
# Processing Record 15 of Set 14 | meadow lake
# Processing Record 16 of Set 14 | tlacotepec
# Processing Record 17 of Set 14 | harstad
# Processing Record 18 of Set 14 | manacor
# Processing Record 19 of Set 14 | zhangjiakou
# Processing Record 20 of Set 14 | tupiza
# Processing Record 21 of Set 14 | college
# Processing Record 22 of Set 14 | tura
# Processing Record 23 of Set 14 | asosa
# Processing Record 24 of Set 14 | viedma
# Processing Record 25 of Set 14 | sorata
# Processing Record 26 of Set 14 | mathathane
# Processing Record 27 of Set 14 | deputatskiy
# Processing Record 28 of Set 14 | campo grande
# Processing Record 29 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 14 | tete
# Processing Record 31 of Set 14 | we
# City not found. Skipping...
# Processing Record 32 of Set 14 | lavrentiya
# Processing Record 33 of Set 14 | tabuk
# Processing Record 34 of Set 14 | bouake
# Processing Record 35 of Set 14 | tamandare
# Processing Record 36 of Set 14 | el alto
# Processing Record 37 of Set 14 | keti bandar
# Processing Record 38 of Set 14 | ayagoz
# Processing Record 39 of Set 14 | palmeiras de goias
# Processing Record 40 of Set 14 | eldorado
# Processing Record 41 of Set 14 | roma
# Processing Record 42 of Set 14 | verkhnyaya inta
# Processing Record 43 of Set 14 | ahuimanu
# Processing Record 44 of Set 14 | ankang
# Processing Record 45 of Set 14 | terrace
# Processing Record 46 of Set 14 | hukuntsi
# Processing Record 47 of Set 14 | muchkapskiy
# Processing Record 48 of Set 14 | haines junction
# Processing Record 49 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 14 | mehamn
# Processing Record 1 of Set 15 | mayor pablo lagerenza
# Processing Record 2 of Set 15 | tabuelan
# Processing Record 3 of Set 15 | muroto
# Processing Record 4 of Set 15 | sayat
# Processing Record 5 of Set 15 | de aar
# Processing Record 6 of Set 15 | katsuura
# Processing Record 7 of Set 15 | kasulu
# Processing Record 8 of Set 15 | selkirk
# Processing Record 9 of Set 15 | lanzhou
# Processing Record 10 of Set 15 | camanducaia
# Processing Record 11 of Set 15 | port hawkesbury
# Processing Record 12 of Set 15 | poretskoye
# Processing Record 13 of Set 15 | bignona
# Processing Record 14 of Set 15 | raudeberg
# Processing Record 15 of Set 15 | matamoros
# Processing Record 16 of Set 15 | sao miguel do araguaia
# Processing Record 17 of Set 15 | imamoglu
# Processing Record 18 of Set 15 | antalaha
# Processing Record 19 of Set 15 | magistralnyy
# Processing Record 20 of Set 15 | sonoita
# Processing Record 21 of Set 15 | samfya
# Processing Record 22 of Set 15 | marzuq
# Processing Record 23 of Set 15 | noumea
# Processing Record 24 of Set 15 | tharrawaddy
# City not found. Skipping...
# Processing Record 25 of Set 15 | xinmin
# Processing Record 26 of Set 15 | chumikan
# Processing Record 27 of Set 15 | foumban
# Processing Record 28 of Set 15 | sorong
# Processing Record 29 of Set 15 | camara de lobos
# Processing Record 30 of Set 15 | kieta
# Processing Record 31 of Set 15 | neepawa
# Processing Record 32 of Set 15 | altea
# Processing Record 33 of Set 15 | baculin
# Processing Record 34 of Set 15 | morehead
# Processing Record 35 of Set 15 | malatya
# Processing Record 36 of Set 15 | matadi
# Processing Record 37 of Set 15 | camana
# Processing Record 38 of Set 15 | gimli
# Processing Record 39 of Set 15 | yar-sale
# Processing Record 40 of Set 15 | fereydun kenar
# Processing Record 41 of Set 15 | emerald
# Processing Record 42 of Set 15 | chapleau
# Processing Record 43 of Set 15 | plouzane
# Processing Record 44 of Set 15 | san-pedro
# Processing Record 45 of Set 15 | ca mau
# Processing Record 46 of Set 15 | siguiri
# Processing Record 47 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 15 | san policarpo
# Processing Record 49 of Set 15 | bani
# Processing Record 50 of Set 15 | anisoc
# Processing Record 1 of Set 16 | khvoynaya
# Processing Record 2 of Set 16 | soma
# Processing Record 3 of Set 16 | port said
# Processing Record 4 of Set 16 | larsnes
# Processing Record 5 of Set 16 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 16 | antofagasta
# Processing Record 7 of Set 16 | ishinomaki
# Processing Record 8 of Set 16 | puerto padre
# Processing Record 9 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 16 | candelaria
# Processing Record 11 of Set 16 | lushoto
# Processing Record 12 of Set 16 | margate
# Processing Record 13 of Set 16 | lakatoro
# Processing Record 14 of Set 16 | glyadyanskoye
# Processing Record 15 of Set 16 | klyuchi
# Processing Record 16 of Set 16 | mizque
# Processing Record 17 of Set 16 | meulaboh
# Processing Record 18 of Set 16 | makinsk
# Processing Record 19 of Set 16 | erenhot
# Processing Record 20 of Set 16 | altamont
# Processing Record 21 of Set 16 | astana
# Processing Record 22 of Set 16 | labuan
# Processing Record 23 of Set 16 | kabare
# Processing Record 24 of Set 16 | rio gallegos
# Processing Record 25 of Set 16 | skibbereen
# Processing Record 26 of Set 16 | vanimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cape Town      ZA -33.9258   18.4232     75.00        77          75
# 1       Bayan      CN  46.0833  127.4000      6.28        92           0
# 2     Mataura      NZ -46.1927  168.8643     54.00        71          72
# 3     Peniche      PT  39.3558   -9.3811     60.01        87         100
# 4      Uchaly      RU  54.2996   59.4521     -9.71        90         100
# 5      Albany      US  42.6001  -73.9662     21.99        51          14
# 6  Mandalgovi      MN  45.7625  106.2708     14.16        84           0
# 7   Saskylakh      RU  71.9167  114.0833    -33.05        81          83
# 8        Sibu      MY   2.3000  111.8167     78.80        89          40
# 9      Castro      BR -24.7911  -50.0119     74.70        77          86
#
#    Wind Speed Current Description
# 0       14.97          light rain
# 1        2.82           clear sky
# 2        5.01       broken clouds
# 3       24.00     overcast clouds
# 4        6.73     overcast clouds
# 5        5.01          few clouds
# 6        6.58           clear sky
# 7        5.08       broken clouds
# 8        1.52          light rain
# 9        4.36     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
